# %%
#loading some stuff 
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import pickle

# %%
#setting system path
import sys
sys.path.append('c:/Users/tpiechowiak/Documents/BEAR/GNOS/sws_machine_learning/')
base_path = 'c:/Users/tpiechowiak/OneDrive - GN Store Nord/GNOS data/'

# %%
#now loading all the necessary data files
#now loading the pickle file containing the audiogram data
with open(base_path + "LatestSQLJson.pkl", "rb") as input_file:
    PAT = pickle.load(input_file)
print("Read Patient data from pickle file")

with open(base_path + "LatestRFTSetting.pkl", "rb") as input_file:
    RFT = pickle.load(input_file)
print("Read RFT from pickle file")

with open(base_path + 'hi_id_low_cluster.pkl','rb') as f:
    hi_id_low_cluster = pickle.load(f)
print("Read low usage cluster hi ids")

with open(base_path + 'Audigram_classes.pkl','rb') as f:
    audiogram_classes = pickle.load(f)
print("Read audiogram data from pickle file")

with open(base_path + 'Bass_states_per_hi.pkl','rb') as f:
    bass_states = pickle.load(f)
print("Read bass state data from pickle file")

with open(base_path + 'Env_use_per_hi.pkl','rb') as f:
    env = pickle.load(f)
print("Read environmental classifier data from pickle file")

with open(base_path + 'Inp_level_per_hi.pkl','rb') as f:
    inp_level = pickle.load(f)
print("Read input level distribution data from pickle file")

with open(base_path + 'rftsettings_blobs_reduced.pkl','rb') as f:
    rft_blob = pickle.load(f)
print("Read rft blobs distribution data from pickle file")
# Out:
# Read Patient data from pickle file
# Read RFT from pickle file
# Read low usage cluster hi ids
# Read audiogram data from pickle file
# Read bass state data from pickle file
# Read environmental classifier data from pickle file
# Read input level distribution data from pickle file
# Read rft blobs distribution data from pickle file

# %%
#now merge in order to connect HearingInstrumentId to GnosHearingInstrumentId
df_1 = pd.merge(PAT['patienthimappings'],PAT['hearinginstruments'],\
                  on='GnosHearingInstrumentId',how='inner')


df_2 = pd.merge(df_1,PAT['patients'],on='PatientId',\
                    how='inner').drop(columns = ['CreatedDate_x',\
                                                 'ModifiedDate_x','CreatedDate_y','ModifiedDate_y'])

# %%
df_3 = pd.merge(audiogram_classes, df_2, on = 'HearingInstrumentId',how = 'inner')
df_4 = pd.merge(rft_blob[['HearingInstrumentId','DeviceId']],df_3, on='HearingInstrumentId',\
               how='inner')

# %%
new_df = df_4[['PatientId',
               'HearingInstrumentId',
               'FirmwareVersion',
               'CountryCode',
               'Earside',
               'StateCode',
               'BrandName',
               'Gender',
               'YearOfBirth',
               'UserExperienceLevel',
               'AudClass',
               'DeviceId'
               ]]

# %%
new_df[new_df['PatientId']=='955DDFCEB78ABC687F91664260B94E3341BC177A728EB7A820D4F65878BBA24D']
# Out:
#                                                  PatientId  \
# 3287402  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287403  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287404  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287405  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600945  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600946  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
#
#                                        HearingInstrumentId FirmwareVersion  \
# 3287402  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287403  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287404  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287405  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 4600945  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
# 4600946  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
#
#         CountryCode  Earside StateCode BrandName  Gender  YearOfBirth  \
# 3287402          US        2        KS   ReSound       1         2018
# 3287403          US        2        KS   ReSound       1         2018
# 3287404          US        2        KS   ReSound       1         2018
# 3287405          US        2        KS   ReSound       1         2018
# 4600945          US        1        KS   ReSound       1         2018
# 4600946          US        1        KS   ReSound       1         2018
#
#          UserExperienceLevel AudClass                  DeviceId
# 3287402                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287403                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287404                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287405                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 4600945                    3       N3  RS.P6.Top.LxRIE312DW.4.0
# 4600946                    3       N3  RS.P6.Top.LxRIE312DW.4.0

# %%
new_df['Cluster_class'] = 0 
new_df.loc[new_df['HearingInstrumentId'].isin(hi_id_low_cluster), 'Cluster_class'] = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
new_df[new_df['HearingInstrumentId'].isin(hi_id_low_cluster)]['Cluster_class']
# Out:
# 4239       1
# 4240       1
# 4241       1
# 4242       1
# 4243       1
#           ..
# 4731185    1
# 4731186    1
# 4731187    1
# 4731188    1
# 4749073    1
# Name: Cluster_class, Length: 105896, dtype: int64

# %%
new_df[new_df['PatientId']=='955DDFCEB78ABC687F91664260B94E3341BC177A728EB7A820D4F65878BBA24D']
# Out:
#                                                  PatientId  \
# 3287402  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287403  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287404  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287405  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600945  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600946  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
#
#                                        HearingInstrumentId FirmwareVersion  \
# 3287402  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287403  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287404  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287405  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 4600945  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
# 4600946  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
#
#         CountryCode  Earside StateCode BrandName  Gender  YearOfBirth  \
# 3287402          US        2        KS   ReSound       1         2018
# 3287403          US        2        KS   ReSound       1         2018
# 3287404          US        2        KS   ReSound       1         2018
# 3287405          US        2        KS   ReSound       1         2018
# 4600945          US        1        KS   ReSound       1         2018
# 4600946          US        1        KS   ReSound       1         2018
#
#          UserExperienceLevel AudClass                  DeviceId  Cluster_class
# 3287402                    3       N2  RS.P6.Top.LxRIE312DW.4.0              1
# 3287403                    3       N2  RS.P6.Top.LxRIE312DW.4.0              1
# 3287404                    3       N2  RS.P6.Top.LxRIE312DW.4.0              1
# 3287405                    3       N2  RS.P6.Top.LxRIE312DW.4.0              1
# 4600945                    3       N3  RS.P6.Top.LxRIE312DW.4.0              0
# 4600946                    3       N3  RS.P6.Top.LxRIE312DW.4.0              0

# %%
AsymLoss = []

cnt = 0
for pat_id, group in new_df.groupby('PatientId'):
    if(cnt%10000 == 0):
        print('Patient =',cnt)
    cnt = cnt + 1    
    
    #check for unilateral fitting => asymmetrical 
    if ((1 not in group['Earside'].values) | (2 not in group['Earside'].values)):        
        AsymLoss.append(pat_id)
        continue
    
    #check for asymmetric loss
    if (~(group[group['Earside'] == 1]['AudClass'].iloc[0]\
          == group[group['Earside'] == 2]['AudClass'].iloc[0])):
        AsymLoss.append(pat_id)
# Out:
# Patient = 0
# Patient = 10000
# Patient = 20000
# Patient = 30000
# Patient = 40000
# Patient = 50000
# Patient = 60000

# %%
new_df['asym'] = 0
new_df.loc[new_df['PatientId'].isin(AsymLoss),'asym'] = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df[new_df['PatientId']=='955DDFCEB78ABC687F91664260B94E3341BC177A728EB7A820D4F65878BBA24D']
# Out:
#                                                  PatientId  \
# 3287402  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287403  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287404  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287405  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600945  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600946  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
#
#                                        HearingInstrumentId FirmwareVersion  \
# 3287402  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287403  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287404  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287405  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 4600945  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
# 4600946  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
#
#         CountryCode  Earside StateCode BrandName  Gender  YearOfBirth  \
# 3287402          US        2        KS   ReSound       1         2018
# 3287403          US        2        KS   ReSound       1         2018
# 3287404          US        2        KS   ReSound       1         2018
# 3287405          US        2        KS   ReSound       1         2018
# 4600945          US        1        KS   ReSound       1         2018
# 4600946          US        1        KS   ReSound       1         2018
#
#          UserExperienceLevel AudClass                  DeviceId  \
# 3287402                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287403                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287404                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287405                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 4600945                    3       N3  RS.P6.Top.LxRIE312DW.4.0
# 4600946                    3       N3  RS.P6.Top.LxRIE312DW.4.0
#
#          Cluster_class  asym
# 3287402              1     1
# 3287403              1     1
# 3287404              1     1
# 3287405              1     1
# 4600945              0     1
# 4600946              0     1

# %%
#we need to make sure that Cluster_Class is 1 for each PatientId when only one devices is 1 

appended_df = []
patid = []
cnt = 0
for pat_id, group in new_df.groupby('PatientId'):
    if(cnt%1000 == 0):
        print('Patient ',cnt)
    if (np.any(group['Cluster_class'] == 1)):
        group['Cluster_class'] = 1
    
    patid.append(pat_id)
    appended_df.append(group) 
    cnt += 1

final_df = pd.concat(appended_df)
# Out:
# Patient  0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# Patient  1000
# Patient  2000
# Patient  3000
# Patient  4000
# Patient  5000
# Patient  6000
# Patient  7000
# Patient  8000
# Patient  9000
# Patient  10000
# Patient  11000
# Patient  12000
# Patient  13000
# Patient  14000
# Patient  15000
# Patient  16000
# Patient  17000
# Patient  18000
# Patient  19000
# Patient  20000
# Patient  21000
# Patient  22000
# Patient  23000
# Patient  24000
# Patient  25000
# Patient  26000
# Patient  27000
# Patient  28000
# Patient  29000
# Patient  30000
# Patient  31000
# Patient  32000
# Patient  33000
# Patient  34000
# Patient  35000
# Patient  36000
# Patient  37000
# Patient  38000
# Patient  39000
# Patient  40000
# Patient  41000
# Patient  42000
# Patient  43000
# Patient  44000
# Patient  45000
# Patient  46000
# Patient  47000
# Patient  48000
# Patient  49000
# Patient  50000
# Patient  51000
# Patient  52000
# Patient  53000
# Patient  54000
# Patient  55000
# Patient  56000
# Patient  57000
# Patient  58000
# Patient  59000
# Patient  60000
# Patient  61000
# Patient  62000
# Patient  63000
# Patient  64000
# Patient  65000
# Patient  66000
# Patient  67000

# %%
final_df[final_df['PatientId']=='955DDFCEB78ABC687F91664260B94E3341BC177A728EB7A820D4F65878BBA24D']
# Out:
#                                                  PatientId  \
# 3287402  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287403  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287404  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287405  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600945  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600946  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
#
#                                        HearingInstrumentId FirmwareVersion  \
# 3287402  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287403  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287404  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287405  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 4600945  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
# 4600946  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
#
#         CountryCode  Earside StateCode BrandName  Gender  YearOfBirth  \
# 3287402          US        2        KS   ReSound       1         2018
# 3287403          US        2        KS   ReSound       1         2018
# 3287404          US        2        KS   ReSound       1         2018
# 3287405          US        2        KS   ReSound       1         2018
# 4600945          US        1        KS   ReSound       1         2018
# 4600946          US        1        KS   ReSound       1         2018
#
#          UserExperienceLevel AudClass                  DeviceId  \
# 3287402                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287403                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287404                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287405                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 4600945                    3       N3  RS.P6.Top.LxRIE312DW.4.0
# 4600946                    3       N3  RS.P6.Top.LxRIE312DW.4.0
#
#          Cluster_class  asym
# 3287402              1     1
# 3287403              1     1
# 3287404              1     1
# 3287405              1     1
# 4600945              1     1
# 4600946              1     1

# %%
#now create age groups
final_df['Age'] = pd.datetime.now().year - final_df['YearOfBirth']
final_df = final_df[final_df['Age'] > 0]
plt.figure(figsize=(10,8))
plt.hist(final_df['Age'],bins = 40, density=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
# (array([1.83158308e-02, 3.43804414e-05, 5.22135484e-04, 7.36989949e-05,
#         8.37988319e-04, 4.16292174e-04, 1.33981232e-04, 2.48955391e-04,
#         1.65203145e-03, 8.48237231e-04, 4.01664181e-04, 1.12654178e-03,
#         7.25529802e-04, 2.01400439e-03, 6.19686492e-04, 1.30645677e-03,
#         4.31535101e-03, 1.28633164e-03, 5.38766673e-03, 2.77466001e-03,
#         3.58069036e-03, 4.38187577e-03, 5.98918470e-03, 4.61154457e-03,
#         7.24178809e-03, 7.22799865e-03, 7.13184522e-03, 8.32640251e-03,
#         1.21728192e-02, 7.68519330e-03, 8.51013755e-03, 2.59331017e-02,
#         1.28985354e-02, 9.25271781e-03, 1.06498309e-02, 1.06119099e-02,
#         1.19691454e-02, 6.98677653e-03, 6.12633377e-03, 2.30115189e-01]),
#  array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  , 12.25, 14.5 , 16.75, 19.  ,
#         21.25, 23.5 , 25.75, 28.  , 30.25, 32.5 , 34.75, 37.  , 39.25,
#         41.5 , 43.75, 46.  , 48.25, 50.5 , 52.75, 55.  , 57.25, 59.5 ,
#         61.75, 64.  , 66.25, 68.5 , 70.75, 73.  , 75.25, 77.5 , 79.75,
#         82.  , 84.25, 86.5 , 88.75, 91.  ]),
#  <a list of 40 Patch objects>)

# %%
#now make age groups 
final_df['AgeGroup'] = ''
final_df.loc[((final_df['Age'] > 0) & (final_df['Age'] <= 20)),'AgeGroup' ] = 'Very Young'
final_df.loc[((final_df['Age'] > 20) & (final_df['Age'] <= 40)),'AgeGroup' ] = 'Young'
final_df.loc[((final_df['Age'] > 40) & (final_df['Age'] <= 60)),'AgeGroup' ] = 'Middle age'
final_df.loc[((final_df['Age'] > 60) & (final_df['Age'] <= 80)),'AgeGroup' ] = 'Old'
final_df.loc[((final_df['Age'] > 80) & ~(final_df['Age'] == 91)),'AgeGroup' ] = 'Very old'
#take out the odd 91 years domain 
final_df.loc[(final_df['Age'] == 91),'AgeGroup' ] = 'Odd'

# %%
#substitute code for left, right
final_df.loc[final_df['Earside'] == 1,'Earside'] = 'left'
final_df.loc[final_df['Earside'] == 2, 'Earside'] = 'right'

# %%
final_df[final_df['PatientId']=='955DDFCEB78ABC687F91664260B94E3341BC177A728EB7A820D4F65878BBA24D']
# Out:
#                                                  PatientId  \
# 3287402  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287403  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287404  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287405  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600945  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600946  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
#
#                                        HearingInstrumentId FirmwareVersion  \
# 3287402  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287403  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287404  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 3287405  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...     L674P674C40
# 4600945  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
# 4600946  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...     L674P674C40
#
#         CountryCode Earside StateCode BrandName  Gender  YearOfBirth  \
# 3287402          US   right        KS   ReSound       1         2018
# 3287403          US   right        KS   ReSound       1         2018
# 3287404          US   right        KS   ReSound       1         2018
# 3287405          US   right        KS   ReSound       1         2018
# 4600945          US    left        KS   ReSound       1         2018
# 4600946          US    left        KS   ReSound       1         2018
#
#          UserExperienceLevel AudClass                  DeviceId  \
# 3287402                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287403                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287404                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 3287405                    3       N2  RS.P6.Top.LxRIE312DW.4.0
# 4600945                    3       N3  RS.P6.Top.LxRIE312DW.4.0
# 4600946                    3       N3  RS.P6.Top.LxRIE312DW.4.0
#
#          Cluster_class  asym  Age    AgeGroup
# 3287402              1     1    2  Very Young
# 3287403              1     1    2  Very Young
# 3287404              1     1    2  Very Young
# 3287405              1     1    2  Very Young
# 4600945              1     1    2  Very Young
# 4600946              1     1    2  Very Young

# %%
#now extract formfactor information from the dataframe
final_df['Formfactor'] = 'Other'
final_df.loc[final_df['DeviceId'].str.contains('ITE'),'Formfactor'] = 'ITE'
final_df.loc[final_df['DeviceId'].str.contains('BTE'),'Formfactor'] = 'BTE'
final_df.loc[final_df['DeviceId'].str.contains('ITC'),'Formfactor'] = 'ITC'
final_df.loc[final_df['DeviceId'].str.contains('CIC'),'Formfactor'] = 'CIC'
final_df.loc[final_df['DeviceId'].str.contains('RIE'),'Formfactor'] = 'RIE'

# %%
final_df.drop(columns= ['FirmwareVersion','DeviceId'], inplace=True)

# %%
final_df.keys()
# Out:
# Index(['PatientId', 'HearingInstrumentId', 'CountryCode', 'Earside',
#        'StateCode', 'BrandName', 'Gender', 'YearOfBirth',
#        'UserExperienceLevel', 'AudClass', 'Cluster_class', 'asym', 'Age',
#        'AgeGroup', 'Formfactor'],
#       dtype='object')

# %%
#now make one-hot-encoding
OHC_enc = pd.get_dummies(final_df, columns=['CountryCode','BrandName',\
                                       'AudClass','Gender','AgeGroup','Formfactor','Earside'])

# %%
OHC_enc = OHC_enc.loc[:,~OHC_enc.columns.duplicated()]

# %%
OHC_enc.keys()
# Out:
# Index(['PatientId', 'HearingInstrumentId', 'StateCode', 'YearOfBirth',
#        'UserExperienceLevel', 'Cluster_class', 'asym', 'Age', 'CountryCode_AR',
#        'CountryCode_AT', 'CountryCode_AU', 'CountryCode_BE', 'CountryCode_BG',
#        'CountryCode_BR', 'CountryCode_CA', 'CountryCode_CH', 'CountryCode_CL',
#        'CountryCode_CO', 'CountryCode_CR', 'CountryCode_CY', 'CountryCode_CZ',
#        'CountryCode_DE', 'CountryCode_DK', 'CountryCode_EC', 'CountryCode_ES',
#        'CountryCode_FI', 'CountryCode_FR', 'CountryCode_GB', 'CountryCode_GR',
#        'CountryCode_HK', 'CountryCode_HU', 'CountryCode_ID', 'CountryCode_IE',
#        'CountryCode_IL', 'CountryCode_IN', 'CountryCode_IS', 'CountryCode_IT',
#        'CountryCode_JP', 'CountryCode_KR', 'CountryCode_KW', 'CountryCode_LB',
#        'CountryCode_MX', 'CountryCode_MY', 'CountryCode_NL', 'CountryCode_NO',
#        'CountryCode_NZ', 'CountryCode_PE', 'CountryCode_PL', 'CountryCode_PT',
#        'CountryCode_RU', 'CountryCode_SE', 'CountryCode_SG', 'CountryCode_SI',
#        'CountryCode_SK', 'CountryCode_TH', 'CountryCode_TR', 'CountryCode_TW',
#        'CountryCode_US', 'CountryCode_ZA', 'BrandName_Beltone',
#        'BrandName_ReSound', 'AudClass_N1', 'AudClass_N2', 'AudClass_N3',
#        'AudClass_N4', 'AudClass_N5', 'AudClass_N6', 'AudClass_N7',
#        'AudClass_S1', 'AudClass_S2', 'AudClass_S3', 'Gender_0', 'Gender_1',
#        'Gender_2', 'AgeGroup_Middle age', 'AgeGroup_Odd', 'AgeGroup_Old',
#        'AgeGroup_Very Young', 'AgeGroup_Very old', 'AgeGroup_Young',
#        'Formfactor_BTE', 'Formfactor_CIC', 'Formfactor_ITC', 'Formfactor_ITE',
#        'Formfactor_RIE', 'Earside_left', 'Earside_right'],
#       dtype='object')

# %%
OHC_enc[OHC_enc['PatientId']=='955DDFCEB78ABC687F91664260B94E3341BC177A728EB7A820D4F65878BBA24D']
# Out:
#                                                  PatientId  \
# 3287402  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287403  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287404  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 3287405  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600945  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600946  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
#
#                                        HearingInstrumentId StateCode  \
# 3287402  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...        KS
# 3287403  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...        KS
# 3287404  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...        KS
# 3287405  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...        KS
# 4600945  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...        KS
# 4600946  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...        KS
#
#          YearOfBirth  UserExperienceLevel  Cluster_class  asym  Age  \
# 3287402         2018                    3              1     1    2
# 3287403         2018                    3              1     1    2
# 3287404         2018                    3              1     1    2
# 3287405         2018                    3              1     1    2
# 4600945         2018                    3              1     1    2
# 4600946         2018                    3              1     1    2
#
#          CountryCode_AR  CountryCode_AT  ...  AgeGroup_Very Young  \
# 3287402               0               0  ...                    1
# 3287403               0               0  ...                    1
# 3287404               0               0  ...                    1
# 3287405               0               0  ...                    1
# 4600945               0               0  ...                    1
# 4600946               0               0  ...                    1
#
#          AgeGroup_Very old  AgeGroup_Young  Formfactor_BTE  Formfactor_CIC  \
# 3287402                  0               0               0               0
# 3287403                  0               0               0               0
# 3287404                  0               0               0               0
# 3287405                  0               0               0               0
# 4600945                  0               0               0               0
# 4600946                  0               0               0               0
#
#          Formfactor_ITC  Formfactor_ITE  Formfactor_RIE  Earside_left  \
# 3287402               0               0               1             0
# 3287403               0               0               1             0
# 3287404               0               0               1             0
# 3287405               0               0               1             0
# 4600945               0               0               1             1
# 4600946               0               0               1             1
#
#          Earside_right
# 3287402              1
# 3287403              1
# 3287404              1
# 3287405              1
# 4600945              0
# 4600946              0
#
# [6 rows x 87 columns]

# %%
OHC_enc.drop_duplicates(subset=['PatientId','HearingInstrumentId'], inplace=True)

# %%
OHC_enc[OHC_enc['PatientId']=='955DDFCEB78ABC687F91664260B94E3341BC177A728EB7A820D4F65878BBA24D']
# Out:
#                                                  PatientId  \
# 3287402  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
# 4600945  955DDFCEB78ABC687F91664260B94E3341BC177A728EB7...
#
#                                        HearingInstrumentId StateCode  \
# 3287402  00E572F3E565F0FCF2F30D519ADCBECD68F3949DD7C369...        KS
# 4600945  238CD7C3D5AF8CA208A5F19C167293885BDA426695A524...        KS
#
#          YearOfBirth  UserExperienceLevel  Cluster_class  asym  Age  \
# 3287402         2018                    3              1     1    2
# 4600945         2018                    3              1     1    2
#
#          CountryCode_AR  CountryCode_AT  ...  AgeGroup_Very Young  \
# 3287402               0               0  ...                    1
# 4600945               0               0  ...                    1
#
#          AgeGroup_Very old  AgeGroup_Young  Formfactor_BTE  Formfactor_CIC  \
# 3287402                  0               0               0               0
# 4600945                  0               0               0               0
#
#          Formfactor_ITC  Formfactor_ITE  Formfactor_RIE  Earside_left  \
# 3287402               0               0               1             0
# 4600945               0               0               1             1
#
#          Earside_right
# 3287402              1
# 4600945              0
#
# [2 rows x 87 columns]

# %%
#now save the data in a .pkl file 
OHC_enc.to_pickle(base_path +  'Demographics_Device_Data_OHC.pkl')
final_df.to_pickle(base_path + 'Demographics_Device_Data.pkl')

# %%
#now load the data again 
base_path = 'c:/Users/tpiechowiak/OneDrive - GN Store Nord/GNOS data/'
with open(base_path + "Demographics_Device_Data_OHC.pkl", "rb") as input_file:
    demo_data = pickle.load(input_file)
print("Read Demographics and device data")
# Out:
# Read Demographics and device data

# %%
demo_data.shape
# Out:
# (132282, 391)

# %%
# iterating the columns 
for col in demo_data.columns: 
    print(col)
# Out:
# PatientId
# HearingInstrumentId
# StateCode
# YearOfBirth
# UserExperienceLevel
# Cluster_class
# unilat
# asym
# Age
# CountryCode_AR
# CountryCode_AT
# CountryCode_AU
# CountryCode_BE
# CountryCode_BG
# CountryCode_BR
# CountryCode_CA
# CountryCode_CH
# CountryCode_CL
# CountryCode_CO
# CountryCode_CR
# CountryCode_CY
# CountryCode_CZ
# CountryCode_DE
# CountryCode_DK
# CountryCode_EC
# CountryCode_ES
# CountryCode_FI
# CountryCode_FR
# CountryCode_GB
# CountryCode_GR
# CountryCode_HK
# CountryCode_HU
# CountryCode_ID
# CountryCode_IE
# CountryCode_IL
# CountryCode_IN
# CountryCode_IS
# CountryCode_IT
# CountryCode_JP
# CountryCode_KR
# CountryCode_KW
# CountryCode_LB
# CountryCode_MX
# CountryCode_MY
# CountryCode_NL
# CountryCode_NO
# CountryCode_NZ
# CountryCode_PE
# CountryCode_PL
# CountryCode_PT
# CountryCode_RU
# CountryCode_SE
# CountryCode_SG
# CountryCode_SI
# CountryCode_SK
# CountryCode_TH
# CountryCode_TR
# CountryCode_TW
# CountryCode_US
# CountryCode_ZA
# BrandName_Beltone
# BrandName_ReSound
# FirmwareVersion_000?NG
# FirmwareVersion_D10037C3700
# FirmwareVersion_D10040C4000
# FirmwareVersion_D10042C4200
# FirmwareVersion_D10043C4300
# FirmwareVersion_D10044C4400
# FirmwareVersion_L674P674C40
# FirmwareVersion_L674P674C41
# AudClass_N1
# AudClass_N2
# AudClass_N3
# AudClass_N4
# AudClass_N5
# AudClass_N6
# AudClass_N7
# AudClass_S1
# AudClass_S2
# AudClass_S3
# Gender_0
# Gender_1
# Gender_2
# AgeGroup_Middle age
# AgeGroup_Old
# AgeGroup_Very Young
# AgeGroup_Very old
# AgeGroup_Young
# DeviceId_BT.D1.Bas.BeRIE13DW.37.0
# DeviceId_BT.D1.Bas.BeRIE13DW.40.0
# DeviceId_BT.D1.Bas.BeRIE13DW.43.0
# DeviceId_BT.D1.Bas.CsCIC10ASWHC.43.0
# DeviceId_BT.D1.Bas.CsCIC10ASWLC.43.0
# DeviceId_BT.D1.Bas.CsCIC10ASWNC.43.0
# DeviceId_BT.D1.Bas.CsITC312DWHC.43.0
# DeviceId_BT.D1.Bas.CsITC312DWNC.43.0
# DeviceId_BT.D1.Bas.CsITE13DWHC.43.0
# DeviceId_BT.D1.Bas.CsMITC312SWHC.43.0
# DeviceId_BT.D1.Bas.CsMITC312SWHO.43.0
# DeviceId_BT.D1.Bas.LxRIE45DW.37.0
# DeviceId_BT.D1.Bas.LxRIE45DW.40.0
# DeviceId_BT.D1.Bas.LxRIE45DW.43.0
# DeviceId_BT.D1.Pls.BeRIE13DW.37.0
# DeviceId_BT.D1.Pls.BeRIE13DW.40.0
# DeviceId_BT.D1.Pls.BeRIE13DW.43.0
# DeviceId_BT.D1.Pls.CsCIC10ASWLC.43.0
# DeviceId_BT.D1.Pls.CsCIC10ASWNC.43.0
# DeviceId_BT.D1.Pls.CsITC312DWHC.43.0
# DeviceId_BT.D1.Pls.CsITC312DWHO.43.0
# DeviceId_BT.D1.Pls.CsITC312DWLC.43.0
# DeviceId_BT.D1.Pls.CsITC312DWNC.43.0
# DeviceId_BT.D1.Pls.CsITE13DWHC.43.0
# DeviceId_BT.D1.Pls.CsMITC312SWHC.43.0
# DeviceId_BT.D1.Pls.CsMITC312SWNC.43.0
# DeviceId_BT.D1.Pls.LxRIE45DW.37.0
# DeviceId_BT.D1.Pls.LxRIE45DW.40.0
# DeviceId_BT.D1.Pls.LxRIE45DW.43.0
# DeviceId_BT.D1.Top.BeRIE13DW.37.0
# DeviceId_BT.D1.Top.BeRIE13DW.40.0
# DeviceId_BT.D1.Top.BeRIE13DW.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWHC.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWHO.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWLC.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWNC.43.0
# DeviceId_BT.D1.Top.CsITC312DWHC.43.0
# DeviceId_BT.D1.Top.CsITC312DWHO.43.0
# DeviceId_BT.D1.Top.CsITC312DWLC.43.0
# DeviceId_BT.D1.Top.CsITC312DWNC.43.0
# DeviceId_BT.D1.Top.CsITE13DWHC.43.0
# DeviceId_BT.D1.Top.CsITE13DWNC.43.0
# DeviceId_BT.D1.Top.CsMITC312SWHO.43.0
# DeviceId_BT.D1.Top.CsMITC312SWNC.43.0
# DeviceId_BT.D1.Top.LxRIE45DW.37.0
# DeviceId_BT.D1.Top.LxRIE45DW.40.0
# DeviceId_BT.D1.Top.LxRIE45DW.42.0
# DeviceId_BT.D1.Top.LxRIE45DW.43.0
# DeviceId_BT.P6.Bas.BeBTE13DW.4.0
# DeviceId_BT.P6.Bas.BeHBTE13DW.4.0
# DeviceId_BT.P6.Bas.BeMBTE312DW.4.0
# DeviceId_BT.P6.Bas.BePBTE13DW.4.0
# DeviceId_BT.P6.Bas.BeRIE13DW.4.0
# DeviceId_BT.P6.Bas.DaITC13DWHC.4.0
# DeviceId_BT.P6.Bas.DaITC13DWHO.4.0
# DeviceId_BT.P6.Bas.DaITC13DWLC.4.0
# DeviceId_BT.P6.Bas.DaITC13DWNC.4.0
# DeviceId_BT.P6.Bas.DaITC13SWHC.4.0
# DeviceId_BT.P6.Bas.DaITC13SWHO.4.0
# DeviceId_BT.P6.Bas.DaITC13SWLC.4.0
# DeviceId_BT.P6.Bas.DaITC13SWNC.4.0
# DeviceId_BT.P6.Bas.DaITE13DWHC.4.0
# DeviceId_BT.P6.Bas.DaITE13DWHO.4.0
# DeviceId_BT.P6.Bas.DaITE13DWNC.4.0
# DeviceId_BT.P6.Bas.DaITE13SWHC.4.0
# DeviceId_BT.P6.Bas.DaITE13SWHO.4.0
# DeviceId_BT.P6.Bas.DaITE13SWNC.4.0
# DeviceId_BT.P6.Bas.DaMITC13SWHC.4.0
# DeviceId_BT.P6.Bas.DaMITC13SWHO.4.0
# DeviceId_BT.P6.Bas.DaMITC13SWNC.4.0
# DeviceId_BT.P6.Bas.LoBTE675DW.4.1
# DeviceId_BT.P6.Bas.LxRIE312DW.4.0
# DeviceId_BT.P6.Bas.LxRIE312DWB.4.0
# DeviceId_BT.P6.Pls.BeBTE13DW.4.0
# DeviceId_BT.P6.Pls.BeHBTE13DW.4.0
# DeviceId_BT.P6.Pls.BeMBTE312DW.4.0
# DeviceId_BT.P6.Pls.BePBTE13DW.4.0
# DeviceId_BT.P6.Pls.BeRIE13DW.4.0
# DeviceId_BT.P6.Pls.DaITC13DWHC.4.0
# DeviceId_BT.P6.Pls.DaITC13DWHO.4.0
# DeviceId_BT.P6.Pls.DaITC13DWLC.4.0
# DeviceId_BT.P6.Pls.DaITC13DWNC.4.0
# DeviceId_BT.P6.Pls.DaITC13SWHC.4.0
# DeviceId_BT.P6.Pls.DaITC13SWLC.4.0
# DeviceId_BT.P6.Pls.DaITC13SWNC.4.0
# DeviceId_BT.P6.Pls.DaITE13DWHC.4.0
# DeviceId_BT.P6.Pls.DaITE13DWHO.4.0
# DeviceId_BT.P6.Pls.DaITE13DWNC.4.0
# DeviceId_BT.P6.Pls.DaITE13SWHC.4.0
# DeviceId_BT.P6.Pls.DaITE13SWHO.4.0
# DeviceId_BT.P6.Pls.DaITE13SWNC.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWHC.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWHO.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWLC.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWNC.4.0
# DeviceId_BT.P6.Pls.LoBTE675DW.4.1
# DeviceId_BT.P6.Pls.LxRIE312DW.4.0
# DeviceId_BT.P6.Pls.LxRIE312DWB.4.0
# DeviceId_BT.P6.Top.BeBTE13DW.4.0
# DeviceId_BT.P6.Top.BeHBTE13DW.4.0
# DeviceId_BT.P6.Top.BeMBTE312DW.4.0
# DeviceId_BT.P6.Top.BePBTE13DW.4.0
# DeviceId_BT.P6.Top.BeRIE13DW.4.0
# DeviceId_BT.P6.Top.DaITC13DWHC.4.0
# DeviceId_BT.P6.Top.DaITC13DWHO.4.0
# DeviceId_BT.P6.Top.DaITC13DWLC.4.0
# DeviceId_BT.P6.Top.DaITC13DWNC.4.0
# DeviceId_BT.P6.Top.DaITC13SWHC.4.0
# DeviceId_BT.P6.Top.DaITC13SWHO.4.0
# DeviceId_BT.P6.Top.DaITC13SWLC.4.0
# DeviceId_BT.P6.Top.DaITC13SWNC.4.0
# DeviceId_BT.P6.Top.DaITE13DWHC.4.0
# DeviceId_BT.P6.Top.DaITE13DWHO.4.0
# DeviceId_BT.P6.Top.DaITE13DWNC.4.0
# DeviceId_BT.P6.Top.DaITE13SWHC.4.0
# DeviceId_BT.P6.Top.DaITE13SWHO.4.0
# DeviceId_BT.P6.Top.DaMITC13SWHC.4.0
# DeviceId_BT.P6.Top.DaMITC13SWHO.4.0
# DeviceId_BT.P6.Top.DaMITC13SWLC.4.0
# DeviceId_BT.P6.Top.DaMITC13SWNC.4.0
# DeviceId_BT.P6.Top.LoBTE675DW.4.1
# DeviceId_BT.P6.Top.LxRIE312DW.4.0
# DeviceId_BT.P6.Top.LxRIE312DWB.4.0
# DeviceId_RS.D1.Bas.BeRIE13DW.37.0
# DeviceId_RS.D1.Bas.BeRIE13DW.40.0
# DeviceId_RS.D1.Bas.BeRIE13DW.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Bas.CsITC312DWHC.42.0
# DeviceId_RS.D1.Bas.CsITC312DWHC.43.0
# DeviceId_RS.D1.Bas.CsITC312DWHO.43.0
# DeviceId_RS.D1.Bas.CsITC312DWLC.43.0
# DeviceId_RS.D1.Bas.CsITC312DWNC.43.0
# DeviceId_RS.D1.Bas.CsITE13DWHC.43.0
# DeviceId_RS.D1.Bas.CsITE13DWHO.43.0
# DeviceId_RS.D1.Bas.CsITE13DWNC.43.0
# DeviceId_RS.D1.Bas.CsMITC312SWHC.43.0
# DeviceId_RS.D1.Bas.CsMITC312SWHO.43.0
# DeviceId_RS.D1.Bas.CsMITC312SWNC.43.0
# DeviceId_RS.D1.Bas.DaCIC10ASWNC.40.0
# DeviceId_RS.D1.Bas.LxRIE45DW.37.0
# DeviceId_RS.D1.Bas.LxRIE45DW.40.0
# DeviceId_RS.D1.Bas.LxRIE45DW.43.0
# DeviceId_RS.D1.Pls.BeRIE13DW.37.0
# DeviceId_RS.D1.Pls.BeRIE13DW.40.0
# DeviceId_RS.D1.Pls.BeRIE13DW.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Pls.CsITC312DWHC.43.0
# DeviceId_RS.D1.Pls.CsITC312DWHO.43.0
# DeviceId_RS.D1.Pls.CsITC312DWLC.43.0
# DeviceId_RS.D1.Pls.CsITC312DWNC.43.0
# DeviceId_RS.D1.Pls.CsITE13DWHC.43.0
# DeviceId_RS.D1.Pls.CsITE13DWHO.43.0
# DeviceId_RS.D1.Pls.CsITE13DWNC.43.0
# DeviceId_RS.D1.Pls.CsMITC312SWHC.43.0
# DeviceId_RS.D1.Pls.CsMITC312SWHO.43.0
# DeviceId_RS.D1.Pls.CsMITC312SWNC.43.0
# DeviceId_RS.D1.Pls.DaCIC10ASWHC.40.0
# DeviceId_RS.D1.Pls.DaCIC10ASWNC.0.0
# DeviceId_RS.D1.Pls.DaCIC10ASWNC.40.0
# DeviceId_RS.D1.Pls.LxRIE45DW.37.0
# DeviceId_RS.D1.Pls.LxRIE45DW.40.0
# DeviceId_RS.D1.Pls.LxRIE45DW.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Prm.CsITC312DWHC.43.0
# DeviceId_RS.D1.Prm.CsITC312DWHO.43.0
# DeviceId_RS.D1.Prm.CsITC312DWNC.43.0
# DeviceId_RS.D1.Top.BeRIE13DW.37.0
# DeviceId_RS.D1.Top.BeRIE13DW.40.0
# DeviceId_RS.D1.Top.BeRIE13DW.43.0
# DeviceId_RS.D1.Top.BeRIE13DWA.37.0
# DeviceId_RS.D1.Top.CsCIC10ASWHC.42.0
# DeviceId_RS.D1.Top.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Top.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Top.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Top.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Top.CsITC312DWHC.43.0
# DeviceId_RS.D1.Top.CsITC312DWHO.43.0
# DeviceId_RS.D1.Top.CsITC312DWLC.43.0
# DeviceId_RS.D1.Top.CsITC312DWNC.43.0
# DeviceId_RS.D1.Top.CsITE13DWHC.43.0
# DeviceId_RS.D1.Top.CsITE13DWHO.43.0
# DeviceId_RS.D1.Top.CsITE13DWNC.43.0
# DeviceId_RS.D1.Top.CsMITC312SWHC.43.0
# DeviceId_RS.D1.Top.CsMITC312SWHO.43.0
# DeviceId_RS.D1.Top.CsMITC312SWNC.43.0
# DeviceId_RS.D1.Top.DaCIC10ASWHC.40.0
# DeviceId_RS.D1.Top.DaCIC10ASWNC.40.0
# DeviceId_RS.D1.Top.LxRIE45DW.37.0
# DeviceId_RS.D1.Top.LxRIE45DW.40.0
# DeviceId_RS.D1.Top.LxRIE45DW.42.0
# DeviceId_RS.D1.Top.LxRIE45DW.43.0
# DeviceId_RS.P6.Bas.BeBTE13DW.4.0
# DeviceId_RS.P6.Bas.BeBTE13DWD.4.0
# DeviceId_RS.P6.Bas.BeHBTE13DW.4.0
# DeviceId_RS.P6.Bas.BeMBTE312DW.4.0
# DeviceId_RS.P6.Bas.BePBTE13DW.4.0
# DeviceId_RS.P6.Bas.BePBTE13DWD.4.0
# DeviceId_RS.P6.Bas.BeRIE13DW.0.0
# DeviceId_RS.P6.Bas.BeRIE13DW.4.0
# DeviceId_RS.P6.Bas.BeRIE13DWD.4.0
# DeviceId_RS.P6.Bas.DaITC13DWHC.4.0
# DeviceId_RS.P6.Bas.DaITC13DWHO.4.0
# DeviceId_RS.P6.Bas.DaITC13DWLC.4.0
# DeviceId_RS.P6.Bas.DaITC13DWNC.4.0
# DeviceId_RS.P6.Bas.DaITC13SWHC.4.0
# DeviceId_RS.P6.Bas.DaITC13SWHO.4.0
# DeviceId_RS.P6.Bas.DaITC13SWLC.4.0
# DeviceId_RS.P6.Bas.DaITC13SWNC.4.0
# DeviceId_RS.P6.Bas.DaITE13DWHC.4.0
# DeviceId_RS.P6.Bas.DaITE13DWHO.4.0
# DeviceId_RS.P6.Bas.DaITE13DWNC.4.0
# DeviceId_RS.P6.Bas.DaITE13SWHC.4.0
# DeviceId_RS.P6.Bas.DaITE13SWHO.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWHC.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWHO.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWLC.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWNC.4.0
# DeviceId_RS.P6.Bas.LoBTE675DW.4.1
# DeviceId_RS.P6.Bas.LoBTE675DWD.4.1
# DeviceId_RS.P6.Bas.LxRIE312DW.4.0
# DeviceId_RS.P6.Bas.LxRIE312DWB.4.0
# DeviceId_RS.P6.Bas.LxRIE312DWD.4.0
# DeviceId_RS.P6.Pls.BeBTE13DW.4.0
# DeviceId_RS.P6.Pls.BeBTE13DWD.4.0
# DeviceId_RS.P6.Pls.BeHBTE13DW.4.0
# DeviceId_RS.P6.Pls.BeMBTE312DW.4.0
# DeviceId_RS.P6.Pls.BePBTE13DW.4.0
# DeviceId_RS.P6.Pls.BePBTE13DWD.4.0
# DeviceId_RS.P6.Pls.BeRIE13DW.4.0
# DeviceId_RS.P6.Pls.BeRIE13DWD.4.0
# DeviceId_RS.P6.Pls.DaITC13DWHC.4.0
# DeviceId_RS.P6.Pls.DaITC13DWHO.4.0
# DeviceId_RS.P6.Pls.DaITC13DWLC.4.0
# DeviceId_RS.P6.Pls.DaITC13DWNC.4.0
# DeviceId_RS.P6.Pls.DaITC13SWHC.4.0
# DeviceId_RS.P6.Pls.DaITC13SWHO.4.0
# DeviceId_RS.P6.Pls.DaITC13SWLC.4.0
# DeviceId_RS.P6.Pls.DaITC13SWNC.4.0
# DeviceId_RS.P6.Pls.DaITE13DWHC.4.0
# DeviceId_RS.P6.Pls.DaITE13DWHO.4.0
# DeviceId_RS.P6.Pls.DaITE13DWNC.4.0
# DeviceId_RS.P6.Pls.DaITE13SWHC.4.0
# DeviceId_RS.P6.Pls.DaITE13SWHO.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWHC.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWHO.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWLC.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWNC.4.0
# DeviceId_RS.P6.Pls.LoBTE675DW.4.1
# DeviceId_RS.P6.Pls.LoBTE675DWD.4.1
# DeviceId_RS.P6.Pls.LxRIE312DW.4.0
# DeviceId_RS.P6.Pls.LxRIE312DWB.4.0
# DeviceId_RS.P6.Pls.LxRIE312DWD.4.0
# DeviceId_RS.P6.Prm.BeBTE13DW.4.0
# DeviceId_RS.P6.Prm.BeBTE13DWD.4.0
# DeviceId_RS.P6.Prm.BeMBTE312DWD.4.0
# DeviceId_RS.P6.Prm.BePBTE13DWD.4.0
# DeviceId_RS.P6.Prm.BeRIE13DWD.4.0
# DeviceId_RS.P6.Prm.LoBTE675DWD.4.1
# DeviceId_RS.P6.Prm.LxRIE312DWD.4.0
# DeviceId_RS.P6.Top.BeBTE13DW.4.0
# DeviceId_RS.P6.Top.BeBTE13DWM.4.0
# DeviceId_RS.P6.Top.BeHBTE13DW.4.0
# DeviceId_RS.P6.Top.BeMBTE312DW.4.0
# DeviceId_RS.P6.Top.BeMBTE312DWM.4.0
# DeviceId_RS.P6.Top.BePBTE13DW.4.0
# DeviceId_RS.P6.Top.BeRIE13DW.0.0
# DeviceId_RS.P6.Top.BeRIE13DW.4.0
# DeviceId_RS.P6.Top.BeRIE13DWC.4.0
# DeviceId_RS.P6.Top.DaITC13DWHC.4.0
# DeviceId_RS.P6.Top.DaITC13DWHO.4.0
# DeviceId_RS.P6.Top.DaITC13DWLC.4.0
# DeviceId_RS.P6.Top.DaITC13DWNC.4.0
# DeviceId_RS.P6.Top.DaITC13SWHC.4.0
# DeviceId_RS.P6.Top.DaITC13SWHO.4.0
# DeviceId_RS.P6.Top.DaITC13SWLC.4.0
# DeviceId_RS.P6.Top.DaITC13SWNC.4.0
# DeviceId_RS.P6.Top.DaITE13DWHC.4.0
# DeviceId_RS.P6.Top.DaITE13DWHO.4.0
# DeviceId_RS.P6.Top.DaITE13DWNC.4.0
# DeviceId_RS.P6.Top.DaITE13SWHO.4.0
# DeviceId_RS.P6.Top.DaMITC13SWHC.4.0
# DeviceId_RS.P6.Top.DaMITC13SWHO.4.0
# DeviceId_RS.P6.Top.DaMITC13SWLC.4.0
# DeviceId_RS.P6.Top.DaMITC13SWNC.4.0
# DeviceId_RS.P6.Top.LoBTE675DW.4.1
# DeviceId_RS.P6.Top.LxRIE312DW.0.0
# DeviceId_RS.P6.Top.LxRIE312DW.4.0
# DeviceId_RS.P6.Top.LxRIE312DWA.4.0
# DeviceId_RS.P6.Top.LxRIE312DWB.4.0
# DeviceId_RS.P6.Top.LxRIE312DWC.4.0
# DeviceId_RS.P6.Top.LxRIE312DWM.4.0
# DeviceId_RS.P6.Top.LxRIE312DWO.4.0
# Earside_left
# Earside_right

# %%
#inputs
X_ = demo_data.loc[:,'UserExperienceLevel':'Earside_right']
X_.drop(columns=['Cluster_class','Age'], inplace=True)
X_.drop(X_.loc[:, 'FirmwareVersion_000\x00\x00\x00\x01?\x00NG':'FirmwareVersion_L674P674C41'], inplace=True, axis=1)

# %%
#targets
Y_ = demo_data['Cluster_class'].values

# %%
# iterating the columns 
for col in X_.columns: 
    print(col)
# Out:
# UserExperienceLevel
# unilat
# asym
# CountryCode_AR
# CountryCode_AT
# CountryCode_AU
# CountryCode_BE
# CountryCode_BG
# CountryCode_BR
# CountryCode_CA
# CountryCode_CH
# CountryCode_CL
# CountryCode_CO
# CountryCode_CR
# CountryCode_CY
# CountryCode_CZ
# CountryCode_DE
# CountryCode_DK
# CountryCode_EC
# CountryCode_ES
# CountryCode_FI
# CountryCode_FR
# CountryCode_GB
# CountryCode_GR
# CountryCode_HK
# CountryCode_HU
# CountryCode_ID
# CountryCode_IE
# CountryCode_IL
# CountryCode_IN
# CountryCode_IS
# CountryCode_IT
# CountryCode_JP
# CountryCode_KR
# CountryCode_KW
# CountryCode_LB
# CountryCode_MX
# CountryCode_MY
# CountryCode_NL
# CountryCode_NO
# CountryCode_NZ
# CountryCode_PE
# CountryCode_PL
# CountryCode_PT
# CountryCode_RU
# CountryCode_SE
# CountryCode_SG
# CountryCode_SI
# CountryCode_SK
# CountryCode_TH
# CountryCode_TR
# CountryCode_TW
# CountryCode_US
# CountryCode_ZA
# BrandName_Beltone
# BrandName_ReSound
# AudClass_N1
# AudClass_N2
# AudClass_N3
# AudClass_N4
# AudClass_N5
# AudClass_N6
# AudClass_N7
# AudClass_S1
# AudClass_S2
# AudClass_S3
# Gender_0
# Gender_1
# Gender_2
# AgeGroup_Middle age
# AgeGroup_Old
# AgeGroup_Very Young
# AgeGroup_Very old
# AgeGroup_Young
# DeviceId_BT.D1.Bas.BeRIE13DW.37.0
# DeviceId_BT.D1.Bas.BeRIE13DW.40.0
# DeviceId_BT.D1.Bas.BeRIE13DW.43.0
# DeviceId_BT.D1.Bas.CsCIC10ASWHC.43.0
# DeviceId_BT.D1.Bas.CsCIC10ASWLC.43.0
# DeviceId_BT.D1.Bas.CsCIC10ASWNC.43.0
# DeviceId_BT.D1.Bas.CsITC312DWHC.43.0
# DeviceId_BT.D1.Bas.CsITC312DWNC.43.0
# DeviceId_BT.D1.Bas.CsITE13DWHC.43.0
# DeviceId_BT.D1.Bas.CsMITC312SWHC.43.0
# DeviceId_BT.D1.Bas.CsMITC312SWHO.43.0
# DeviceId_BT.D1.Bas.LxRIE45DW.37.0
# DeviceId_BT.D1.Bas.LxRIE45DW.40.0
# DeviceId_BT.D1.Bas.LxRIE45DW.43.0
# DeviceId_BT.D1.Pls.BeRIE13DW.37.0
# DeviceId_BT.D1.Pls.BeRIE13DW.40.0
# DeviceId_BT.D1.Pls.BeRIE13DW.43.0
# DeviceId_BT.D1.Pls.CsCIC10ASWLC.43.0
# DeviceId_BT.D1.Pls.CsCIC10ASWNC.43.0
# DeviceId_BT.D1.Pls.CsITC312DWHC.43.0
# DeviceId_BT.D1.Pls.CsITC312DWHO.43.0
# DeviceId_BT.D1.Pls.CsITC312DWLC.43.0
# DeviceId_BT.D1.Pls.CsITC312DWNC.43.0
# DeviceId_BT.D1.Pls.CsITE13DWHC.43.0
# DeviceId_BT.D1.Pls.CsMITC312SWHC.43.0
# DeviceId_BT.D1.Pls.CsMITC312SWNC.43.0
# DeviceId_BT.D1.Pls.LxRIE45DW.37.0
# DeviceId_BT.D1.Pls.LxRIE45DW.40.0
# DeviceId_BT.D1.Pls.LxRIE45DW.43.0
# DeviceId_BT.D1.Top.BeRIE13DW.37.0
# DeviceId_BT.D1.Top.BeRIE13DW.40.0
# DeviceId_BT.D1.Top.BeRIE13DW.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWHC.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWHO.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWLC.43.0
# DeviceId_BT.D1.Top.CsCIC10ASWNC.43.0
# DeviceId_BT.D1.Top.CsITC312DWHC.43.0
# DeviceId_BT.D1.Top.CsITC312DWHO.43.0
# DeviceId_BT.D1.Top.CsITC312DWLC.43.0
# DeviceId_BT.D1.Top.CsITC312DWNC.43.0
# DeviceId_BT.D1.Top.CsITE13DWHC.43.0
# DeviceId_BT.D1.Top.CsITE13DWNC.43.0
# DeviceId_BT.D1.Top.CsMITC312SWHO.43.0
# DeviceId_BT.D1.Top.CsMITC312SWNC.43.0
# DeviceId_BT.D1.Top.LxRIE45DW.37.0
# DeviceId_BT.D1.Top.LxRIE45DW.40.0
# DeviceId_BT.D1.Top.LxRIE45DW.42.0
# DeviceId_BT.D1.Top.LxRIE45DW.43.0
# DeviceId_BT.P6.Bas.BeBTE13DW.4.0
# DeviceId_BT.P6.Bas.BeHBTE13DW.4.0
# DeviceId_BT.P6.Bas.BeMBTE312DW.4.0
# DeviceId_BT.P6.Bas.BePBTE13DW.4.0
# DeviceId_BT.P6.Bas.BeRIE13DW.4.0
# DeviceId_BT.P6.Bas.DaITC13DWHC.4.0
# DeviceId_BT.P6.Bas.DaITC13DWHO.4.0
# DeviceId_BT.P6.Bas.DaITC13DWLC.4.0
# DeviceId_BT.P6.Bas.DaITC13DWNC.4.0
# DeviceId_BT.P6.Bas.DaITC13SWHC.4.0
# DeviceId_BT.P6.Bas.DaITC13SWHO.4.0
# DeviceId_BT.P6.Bas.DaITC13SWLC.4.0
# DeviceId_BT.P6.Bas.DaITC13SWNC.4.0
# DeviceId_BT.P6.Bas.DaITE13DWHC.4.0
# DeviceId_BT.P6.Bas.DaITE13DWHO.4.0
# DeviceId_BT.P6.Bas.DaITE13DWNC.4.0
# DeviceId_BT.P6.Bas.DaITE13SWHC.4.0
# DeviceId_BT.P6.Bas.DaITE13SWHO.4.0
# DeviceId_BT.P6.Bas.DaITE13SWNC.4.0
# DeviceId_BT.P6.Bas.DaMITC13SWHC.4.0
# DeviceId_BT.P6.Bas.DaMITC13SWHO.4.0
# DeviceId_BT.P6.Bas.DaMITC13SWNC.4.0
# DeviceId_BT.P6.Bas.LoBTE675DW.4.1
# DeviceId_BT.P6.Bas.LxRIE312DW.4.0
# DeviceId_BT.P6.Bas.LxRIE312DWB.4.0
# DeviceId_BT.P6.Pls.BeBTE13DW.4.0
# DeviceId_BT.P6.Pls.BeHBTE13DW.4.0
# DeviceId_BT.P6.Pls.BeMBTE312DW.4.0
# DeviceId_BT.P6.Pls.BePBTE13DW.4.0
# DeviceId_BT.P6.Pls.BeRIE13DW.4.0
# DeviceId_BT.P6.Pls.DaITC13DWHC.4.0
# DeviceId_BT.P6.Pls.DaITC13DWHO.4.0
# DeviceId_BT.P6.Pls.DaITC13DWLC.4.0
# DeviceId_BT.P6.Pls.DaITC13DWNC.4.0
# DeviceId_BT.P6.Pls.DaITC13SWHC.4.0
# DeviceId_BT.P6.Pls.DaITC13SWLC.4.0
# DeviceId_BT.P6.Pls.DaITC13SWNC.4.0
# DeviceId_BT.P6.Pls.DaITE13DWHC.4.0
# DeviceId_BT.P6.Pls.DaITE13DWHO.4.0
# DeviceId_BT.P6.Pls.DaITE13DWNC.4.0
# DeviceId_BT.P6.Pls.DaITE13SWHC.4.0
# DeviceId_BT.P6.Pls.DaITE13SWHO.4.0
# DeviceId_BT.P6.Pls.DaITE13SWNC.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWHC.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWHO.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWLC.4.0
# DeviceId_BT.P6.Pls.DaMITC13SWNC.4.0
# DeviceId_BT.P6.Pls.LoBTE675DW.4.1
# DeviceId_BT.P6.Pls.LxRIE312DW.4.0
# DeviceId_BT.P6.Pls.LxRIE312DWB.4.0
# DeviceId_BT.P6.Top.BeBTE13DW.4.0
# DeviceId_BT.P6.Top.BeHBTE13DW.4.0
# DeviceId_BT.P6.Top.BeMBTE312DW.4.0
# DeviceId_BT.P6.Top.BePBTE13DW.4.0
# DeviceId_BT.P6.Top.BeRIE13DW.4.0
# DeviceId_BT.P6.Top.DaITC13DWHC.4.0
# DeviceId_BT.P6.Top.DaITC13DWHO.4.0
# DeviceId_BT.P6.Top.DaITC13DWLC.4.0
# DeviceId_BT.P6.Top.DaITC13DWNC.4.0
# DeviceId_BT.P6.Top.DaITC13SWHC.4.0
# DeviceId_BT.P6.Top.DaITC13SWHO.4.0
# DeviceId_BT.P6.Top.DaITC13SWLC.4.0
# DeviceId_BT.P6.Top.DaITC13SWNC.4.0
# DeviceId_BT.P6.Top.DaITE13DWHC.4.0
# DeviceId_BT.P6.Top.DaITE13DWHO.4.0
# DeviceId_BT.P6.Top.DaITE13DWNC.4.0
# DeviceId_BT.P6.Top.DaITE13SWHC.4.0
# DeviceId_BT.P6.Top.DaITE13SWHO.4.0
# DeviceId_BT.P6.Top.DaMITC13SWHC.4.0
# DeviceId_BT.P6.Top.DaMITC13SWHO.4.0
# DeviceId_BT.P6.Top.DaMITC13SWLC.4.0
# DeviceId_BT.P6.Top.DaMITC13SWNC.4.0
# DeviceId_BT.P6.Top.LoBTE675DW.4.1
# DeviceId_BT.P6.Top.LxRIE312DW.4.0
# DeviceId_BT.P6.Top.LxRIE312DWB.4.0
# DeviceId_RS.D1.Bas.BeRIE13DW.37.0
# DeviceId_RS.D1.Bas.BeRIE13DW.40.0
# DeviceId_RS.D1.Bas.BeRIE13DW.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Bas.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Bas.CsITC312DWHC.42.0
# DeviceId_RS.D1.Bas.CsITC312DWHC.43.0
# DeviceId_RS.D1.Bas.CsITC312DWHO.43.0
# DeviceId_RS.D1.Bas.CsITC312DWLC.43.0
# DeviceId_RS.D1.Bas.CsITC312DWNC.43.0
# DeviceId_RS.D1.Bas.CsITE13DWHC.43.0
# DeviceId_RS.D1.Bas.CsITE13DWHO.43.0
# DeviceId_RS.D1.Bas.CsITE13DWNC.43.0
# DeviceId_RS.D1.Bas.CsMITC312SWHC.43.0
# DeviceId_RS.D1.Bas.CsMITC312SWHO.43.0
# DeviceId_RS.D1.Bas.CsMITC312SWNC.43.0
# DeviceId_RS.D1.Bas.DaCIC10ASWNC.40.0
# DeviceId_RS.D1.Bas.LxRIE45DW.37.0
# DeviceId_RS.D1.Bas.LxRIE45DW.40.0
# DeviceId_RS.D1.Bas.LxRIE45DW.43.0
# DeviceId_RS.D1.Pls.BeRIE13DW.37.0
# DeviceId_RS.D1.Pls.BeRIE13DW.40.0
# DeviceId_RS.D1.Pls.BeRIE13DW.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Pls.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Pls.CsITC312DWHC.43.0
# DeviceId_RS.D1.Pls.CsITC312DWHO.43.0
# DeviceId_RS.D1.Pls.CsITC312DWLC.43.0
# DeviceId_RS.D1.Pls.CsITC312DWNC.43.0
# DeviceId_RS.D1.Pls.CsITE13DWHC.43.0
# DeviceId_RS.D1.Pls.CsITE13DWHO.43.0
# DeviceId_RS.D1.Pls.CsITE13DWNC.43.0
# DeviceId_RS.D1.Pls.CsMITC312SWHC.43.0
# DeviceId_RS.D1.Pls.CsMITC312SWHO.43.0
# DeviceId_RS.D1.Pls.CsMITC312SWNC.43.0
# DeviceId_RS.D1.Pls.DaCIC10ASWHC.40.0
# DeviceId_RS.D1.Pls.DaCIC10ASWNC.0.0
# DeviceId_RS.D1.Pls.DaCIC10ASWNC.40.0
# DeviceId_RS.D1.Pls.LxRIE45DW.37.0
# DeviceId_RS.D1.Pls.LxRIE45DW.40.0
# DeviceId_RS.D1.Pls.LxRIE45DW.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Prm.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Prm.CsITC312DWHC.43.0
# DeviceId_RS.D1.Prm.CsITC312DWHO.43.0
# DeviceId_RS.D1.Prm.CsITC312DWNC.43.0
# DeviceId_RS.D1.Top.BeRIE13DW.37.0
# DeviceId_RS.D1.Top.BeRIE13DW.40.0
# DeviceId_RS.D1.Top.BeRIE13DW.43.0
# DeviceId_RS.D1.Top.BeRIE13DWA.37.0
# DeviceId_RS.D1.Top.CsCIC10ASWHC.42.0
# DeviceId_RS.D1.Top.CsCIC10ASWHC.43.0
# DeviceId_RS.D1.Top.CsCIC10ASWHO.43.0
# DeviceId_RS.D1.Top.CsCIC10ASWLC.43.0
# DeviceId_RS.D1.Top.CsCIC10ASWNC.43.0
# DeviceId_RS.D1.Top.CsITC312DWHC.43.0
# DeviceId_RS.D1.Top.CsITC312DWHO.43.0
# DeviceId_RS.D1.Top.CsITC312DWLC.43.0
# DeviceId_RS.D1.Top.CsITC312DWNC.43.0
# DeviceId_RS.D1.Top.CsITE13DWHC.43.0
# DeviceId_RS.D1.Top.CsITE13DWHO.43.0
# DeviceId_RS.D1.Top.CsITE13DWNC.43.0
# DeviceId_RS.D1.Top.CsMITC312SWHC.43.0
# DeviceId_RS.D1.Top.CsMITC312SWHO.43.0
# DeviceId_RS.D1.Top.CsMITC312SWNC.43.0
# DeviceId_RS.D1.Top.DaCIC10ASWHC.40.0
# DeviceId_RS.D1.Top.DaCIC10ASWNC.40.0
# DeviceId_RS.D1.Top.LxRIE45DW.37.0
# DeviceId_RS.D1.Top.LxRIE45DW.40.0
# DeviceId_RS.D1.Top.LxRIE45DW.42.0
# DeviceId_RS.D1.Top.LxRIE45DW.43.0
# DeviceId_RS.P6.Bas.BeBTE13DW.4.0
# DeviceId_RS.P6.Bas.BeBTE13DWD.4.0
# DeviceId_RS.P6.Bas.BeHBTE13DW.4.0
# DeviceId_RS.P6.Bas.BeMBTE312DW.4.0
# DeviceId_RS.P6.Bas.BePBTE13DW.4.0
# DeviceId_RS.P6.Bas.BePBTE13DWD.4.0
# DeviceId_RS.P6.Bas.BeRIE13DW.0.0
# DeviceId_RS.P6.Bas.BeRIE13DW.4.0
# DeviceId_RS.P6.Bas.BeRIE13DWD.4.0
# DeviceId_RS.P6.Bas.DaITC13DWHC.4.0
# DeviceId_RS.P6.Bas.DaITC13DWHO.4.0
# DeviceId_RS.P6.Bas.DaITC13DWLC.4.0
# DeviceId_RS.P6.Bas.DaITC13DWNC.4.0
# DeviceId_RS.P6.Bas.DaITC13SWHC.4.0
# DeviceId_RS.P6.Bas.DaITC13SWHO.4.0
# DeviceId_RS.P6.Bas.DaITC13SWLC.4.0
# DeviceId_RS.P6.Bas.DaITC13SWNC.4.0
# DeviceId_RS.P6.Bas.DaITE13DWHC.4.0
# DeviceId_RS.P6.Bas.DaITE13DWHO.4.0
# DeviceId_RS.P6.Bas.DaITE13DWNC.4.0
# DeviceId_RS.P6.Bas.DaITE13SWHC.4.0
# DeviceId_RS.P6.Bas.DaITE13SWHO.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWHC.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWHO.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWLC.4.0
# DeviceId_RS.P6.Bas.DaMITC13SWNC.4.0
# DeviceId_RS.P6.Bas.LoBTE675DW.4.1
# DeviceId_RS.P6.Bas.LoBTE675DWD.4.1
# DeviceId_RS.P6.Bas.LxRIE312DW.4.0
# DeviceId_RS.P6.Bas.LxRIE312DWB.4.0
# DeviceId_RS.P6.Bas.LxRIE312DWD.4.0
# DeviceId_RS.P6.Pls.BeBTE13DW.4.0
# DeviceId_RS.P6.Pls.BeBTE13DWD.4.0
# DeviceId_RS.P6.Pls.BeHBTE13DW.4.0
# DeviceId_RS.P6.Pls.BeMBTE312DW.4.0
# DeviceId_RS.P6.Pls.BePBTE13DW.4.0
# DeviceId_RS.P6.Pls.BePBTE13DWD.4.0
# DeviceId_RS.P6.Pls.BeRIE13DW.4.0
# DeviceId_RS.P6.Pls.BeRIE13DWD.4.0
# DeviceId_RS.P6.Pls.DaITC13DWHC.4.0
# DeviceId_RS.P6.Pls.DaITC13DWHO.4.0
# DeviceId_RS.P6.Pls.DaITC13DWLC.4.0
# DeviceId_RS.P6.Pls.DaITC13DWNC.4.0
# DeviceId_RS.P6.Pls.DaITC13SWHC.4.0
# DeviceId_RS.P6.Pls.DaITC13SWHO.4.0
# DeviceId_RS.P6.Pls.DaITC13SWLC.4.0
# DeviceId_RS.P6.Pls.DaITC13SWNC.4.0
# DeviceId_RS.P6.Pls.DaITE13DWHC.4.0
# DeviceId_RS.P6.Pls.DaITE13DWHO.4.0
# DeviceId_RS.P6.Pls.DaITE13DWNC.4.0
# DeviceId_RS.P6.Pls.DaITE13SWHC.4.0
# DeviceId_RS.P6.Pls.DaITE13SWHO.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWHC.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWHO.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWLC.4.0
# DeviceId_RS.P6.Pls.DaMITC13SWNC.4.0
# DeviceId_RS.P6.Pls.LoBTE675DW.4.1
# DeviceId_RS.P6.Pls.LoBTE675DWD.4.1
# DeviceId_RS.P6.Pls.LxRIE312DW.4.0
# DeviceId_RS.P6.Pls.LxRIE312DWB.4.0
# DeviceId_RS.P6.Pls.LxRIE312DWD.4.0
# DeviceId_RS.P6.Prm.BeBTE13DW.4.0
# DeviceId_RS.P6.Prm.BeBTE13DWD.4.0
# DeviceId_RS.P6.Prm.BeMBTE312DWD.4.0
# DeviceId_RS.P6.Prm.BePBTE13DWD.4.0
# DeviceId_RS.P6.Prm.BeRIE13DWD.4.0
# DeviceId_RS.P6.Prm.LoBTE675DWD.4.1
# DeviceId_RS.P6.Prm.LxRIE312DWD.4.0
# DeviceId_RS.P6.Top.BeBTE13DW.4.0
# DeviceId_RS.P6.Top.BeBTE13DWM.4.0
# DeviceId_RS.P6.Top.BeHBTE13DW.4.0
# DeviceId_RS.P6.Top.BeMBTE312DW.4.0
# DeviceId_RS.P6.Top.BeMBTE312DWM.4.0
# DeviceId_RS.P6.Top.BePBTE13DW.4.0
# DeviceId_RS.P6.Top.BeRIE13DW.0.0
# DeviceId_RS.P6.Top.BeRIE13DW.4.0
# DeviceId_RS.P6.Top.BeRIE13DWC.4.0
# DeviceId_RS.P6.Top.DaITC13DWHC.4.0
# DeviceId_RS.P6.Top.DaITC13DWHO.4.0
# DeviceId_RS.P6.Top.DaITC13DWLC.4.0
# DeviceId_RS.P6.Top.DaITC13DWNC.4.0
# DeviceId_RS.P6.Top.DaITC13SWHC.4.0
# DeviceId_RS.P6.Top.DaITC13SWHO.4.0
# DeviceId_RS.P6.Top.DaITC13SWLC.4.0
# DeviceId_RS.P6.Top.DaITC13SWNC.4.0
# DeviceId_RS.P6.Top.DaITE13DWHC.4.0
# DeviceId_RS.P6.Top.DaITE13DWHO.4.0
# DeviceId_RS.P6.Top.DaITE13DWNC.4.0
# DeviceId_RS.P6.Top.DaITE13SWHO.4.0
# DeviceId_RS.P6.Top.DaMITC13SWHC.4.0
# DeviceId_RS.P6.Top.DaMITC13SWHO.4.0
# DeviceId_RS.P6.Top.DaMITC13SWLC.4.0
# DeviceId_RS.P6.Top.DaMITC13SWNC.4.0
# DeviceId_RS.P6.Top.LoBTE675DW.4.1
# DeviceId_RS.P6.Top.LxRIE312DW.0.0
# DeviceId_RS.P6.Top.LxRIE312DW.4.0
# DeviceId_RS.P6.Top.LxRIE312DWA.4.0
# DeviceId_RS.P6.Top.LxRIE312DWB.4.0
# DeviceId_RS.P6.Top.LxRIE312DWC.4.0
# DeviceId_RS.P6.Top.LxRIE312DWM.4.0
# DeviceId_RS.P6.Top.LxRIE312DWO.4.0
# Earside_left
# Earside_right

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.tree import plot_tree

# %%
tr = DecisionTreeClassifier(criterion='gini', max_depth=4, min_samples_split = 10, min_samples_leaf = 10)

# %%
tr.fit(X_,Y_)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
export_graphviz(tr,out_file='tree.dot', feature_names=X_.columns,filled=False, rounded=True,
               proportion=True,
               leaves_parallel=True)

# %%
from subprocess import call
call(['dot', '-T', 'pdf', 'tree.dot', '-o', 'tree.pdf'])
# Out:
# 0

# %%
X_.columns[np.where(tr.feature_importances_ > 0)]
# Out:
# Index(['CountryCode_AU', 'CountryCode_DK', 'CountryCode_HU', 'CountryCode_JP',
#        'AudClass_N2', 'Gender_0', 'DeviceId_BT.P6.Bas.BeBTE13DW.4.0',
#        'DeviceId_RS.D1.Pls.BeRIE13DW.37.0',
#        'DeviceId_RS.D1.Top.LxRIE45DW.37.0',
#        'DeviceId_RS.P6.Top.LxRIE312DW.4.0'],
#       dtype='object')

# %%
tr.feature_importances_[np.where(tr.feature_importances_ > 0)]
# Out:
# array([0.08037968, 0.1059227 , 0.25999414, 0.0834984 , 0.28151   ,
#        0.09894961, 0.0509177 , 0.03882777])
